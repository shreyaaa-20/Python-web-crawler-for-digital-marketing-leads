# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyaaa-20/Python-web-crawler-for-digital-marketing-leads/blob/main/WebCrawler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup

def web_crawler(query):
    print(f"Searching for: {query}\n")

    url = f"https://html.duckduckgo.com/html/?q={query}"

    headers = {
        "User-Agent": "Mozilla/5.0"
    }

    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, "html.parser")

    results = []

    for result in soup.find_all("a", class_="result__a", limit=10):
        title = result.text
        link = result.get("href")

        results.append({
            "title": title,
            "link": link
        })

    return results


# Test
data = web_crawler("Digital Marketing services in mumbai")

for i, item in enumerate(data, 1):
    print(f"{i}. {item['title']}")
    print(f"   {item['link']}\n")
# Out:
# Searching for: Digital Marketing services in mumbai
#
# 1. 20 Best Digital Marketing Agencies in Mumbai - 2026 Updated
#    //duckduckgo.com/l/?uddg=https%3A%2F%2Fiide.co%2Fblog%2Fdigital%2Dmarketing%2Dagencies%2Din%2Dmumbai%2F&rut=897a983bf0a3033f12c59ce73b1d00fb9c6508cf8edbda828a9c4fda8d1894ea
#
# 2. Digital Marketing Agency Mumbai | SEO, PPC & Social Media | AMW®
#    //duckduckgo.com/l/?uddg=https%3A%2F%2Famworldgroup.com%2Fservices%2Fdigital%2Dmarketing%2Fmumbai&rut=7a8dac5e67b05e7337d4ff737338d3cc2fb5792814197780bc5741063f563e70
#
# 3. Digital Marketing Agency & Company in Mumbai, India | 1702 Digital
#    //duckduckgo.com/l/?uddg=https%3A%2F%2F1702digital.com%2F&rut=0669784827fba330d6aa3f7bd7843791ec846de1c93014350f5a75ae6e8b554c
#
# 4. Digital Marketing Agency in Mumbai - Digital Markting Agency
#    //duckduckgo.com/l/?uddg=https%3A%2F%2Fwww.owlprime.com%2Fdigital%2Dmarketing%2Dagency%2Din%2Dmumbai%2D2%2F&rut=07b9ee6f24263f8d9ccec5a4f1f603f40345aa0741f6da7a26ade294366b1ff7
# ...

# %%
import json

with open("leads.json", "w") as file:
    json.dump(data, file, indent=4)

print("Data saved to leads.json")
# Out:
# Data saved to leads.json
